# %% [markdown]
# <a href="https://colab.research.google.com/github/KATE-ABIGAIL/CPEN65-2/blob/main/Trees_Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
6. Children of node 16?

    Nodes = 13, 6, 60

7. Parent of node 1?

    Nodes = 7

8. Siblings of node 23?

    Nodes =

9. Ancestors of node 9?

    Nodes = 4, 12, 7, 22

10. Descendants of node 16?

     Nodes = 13, 23, 6, 60, 21

11. Leaves.

     Nodes = 23, 6, 21, 20, 9, 1

12. Non Leaves.

     Nodes = 13, 16, 60, 12, 7, 22

13. Depth of node 4?
      = 3

14. Degree of the tree?
      = 3

15. Height of the tree?
      = 4

16. Weight of the tree?
      = 6

17. Is the tree a binary tree?

     No, node 16 has a degree/number of children of 3 

18. Removing 6, is the tree a full binary tree?

     No, nodes 13 and 60 only has one child or a degree of one

19. Removing 6, is the tree a complete binary tree?

     No because the leaf node 1 has a depth of two, leaf nodes 23, 21 and 20 has a depth of 3, and leaf node 9 has a depth of 4. Also, non leaf nodes 13, 
     60 and 4 are in degree of one and the non leaf nodes 16, 12, 7 and 22 are in degree of two.

20. Is a full binary tree complete?

     No because in all full binary tree, all nodes have exactly 2 degress that is one of the requirements to be called complete, however, it also states that 
     in order to be considered as complete k-ary tree, all leaf nodes should always have the same depth, but the depths of the leafs of a full binary tree can vary
     that is why a full binary tree can't be considered as complete.

21. Is a complete binary tree full?

     Yes, since according to the requirements, a complete 2-ary tree should contain leaf nodes with the same depth and that all of the non leaf nodes of a complete
     2-ary has a degree of two.

22. How many leaves does a complete n-ary tree of height h have?.

     To find the leaves: n^h
     complete 3-ary tree with a height of 4
     n = 3 , h = 4
     = 3^4 = 81
     total number of leaf nodes on the tree (m) = 81.

23. What is the height of a complete n-ary tree with m leaves?.

     To find the height: log base of n (m)
     complete 3-ary tree with 81 leaves
     n = 3 , m = 81
     = log base of 2 (81)
     h = 4.


24. What is the number of internal nodes of a complete n-ary tree of height h?.
      
     To find the number of internal nodes: (n^h-1)/(n-1)
     complete 3-ary tree with a height of 4
     h = 4 , n = 3
     = (3^4-1)/(3-1)
     internal nodes = 40


25. What is the total number of nodes a complete n-ary tree of h have?

     To find the total number of node: (n^(h+1)-1)/(n-1)
     complete 3-ary tree with a height of 4
     h = 4 , n = 3
     By Substitution: (3^(4+1)-1)/(3-1)
     total number of nodes = 121
